# %%
import pandas as pd 
import geopandas as gpd
import csv
from pathlib import Path

from collections import OrderedDict

# %%
moneyball_dir = Path.cwd() / "data"
out_dir = Path.cwd() / "out-files"

# %%
# Util method to come between state formats 
# returnType must be either 'full' 'two_digit' or 'FIPS'
def get_state_code(input, returnType = 'FIPS'):
    if (returnType != 'full' and returnType != 'two_digit' and returnType != 'FIPS'):
        raise ValueError("returnType must be either 'full' 'two_digit' or 'FIPS'")

    code_hash = {
        'AL': {'full': 'Alabama', 'two_digit': 'AL', 'FIPS': 1},
        'AK': {'full': 'Alaska', 'two_digit': 'AK', 'FIPS': 2},
        'AZ': {'full': 'Arizona', 'two_digit': 'AZ', 'FIPS': 4},
        'AR': {'full': 'Arkansas', 'two_digit': 'AR', 'FIPS': 5},
        'CA': {'full': 'California', 'two_digit': 'CA', 'FIPS': 6},
        'CO': {'full': 'Colorado', 'two_digit': 'CO', 'FIPS': 8},
        'CT': {'full': 'Connecticut', 'two_digit': 'CT', 'FIPS': 9},
        'DE': {'full': 'Delaware', 'two_digit': 'DE', 'FIPS': 10},
        'DC': {'full': 'District of Columbia', 'two_digit': 'DC', 'FIPS': 11},
        'FL': {'full': 'Florida', 'two_digit': 'FL', 'FIPS': 12},
        'GA': {'full': 'Georgia', 'two_digit': 'GA', 'FIPS': 13},
        'HI': {'full': 'Hawaii', 'two_digit': 'HI', 'FIPS': 15},
        'ID': {'full': 'Idaho', 'two_digit': 'ID', 'FIPS': 16},
        'IL': {'full': 'Illinois', 'two_digit': 'IL', 'FIPS': 17},
        'IN': {'full': 'Indiana', 'two_digit': 'IN', 'FIPS': 18},
        'IA': {'full': 'Iowa', 'two_digit': 'IA', 'FIPS': 19},
        'KS': {'full': 'Kansas', 'two_digit': 'KS', 'FIPS': 20},
        'KY': {'full': 'Kentucky', 'two_digit': 'KY', 'FIPS': 21},
        'LA': {'full': 'Louisiana', 'two_digit': 'LA', 'FIPS': 22},
        'ME': {'full': 'Maine', 'two_digit': 'ME', 'FIPS': 23},
        'MD': {'full': 'Maryland', 'two_digit': 'MD', 'FIPS': 24},
        'MA': {'full': 'Massachusetts', 'two_digit': 'MA', 'FIPS': 25},
        'MI': {'full': 'Michigan', 'two_digit': 'MI', 'FIPS': 26},
        'MN': {'full': 'Minnesota', 'two_digit': 'MN', 'FIPS': 27},
        'MS': {'full': 'Mississippi', 'two_digit': 'MS', 'FIPS': 28},
        'MO': {'full': 'Missouri', 'two_digit': 'MO', 'FIPS': 29},
        'MT': {'full': 'Montana', 'two_digit': 'MT', 'FIPS': 30},
        'NE': {'full': 'Nebraska', 'two_digit': 'NE', 'FIPS': 31},
        'NV': {'full': 'Nevada', 'two_digit': 'NV', 'FIPS': 32},
        'NH': {'full': 'New Hampshire', 'two_digit': 'NH', 'FIPS': 33},
        'NJ': {'full': 'New Jersey', 'two_digit': 'NJ', 'FIPS': 34},
        'NM': {'full': 'New Mexico', 'two_digit': 'NM', 'FIPS': 35},
        'NY': {'full': 'New York', 'two_digit': 'NY', 'FIPS': 36},
        'NC': {'full': 'North Carolina', 'two_digit': 'NC', 'FIPS': 37},
        'ND': {'full': 'North Dakota', 'two_digit': 'ND', 'FIPS': 38},
        'OH': {'full': 'Ohio', 'two_digit': 'OH', 'FIPS': 39},
        'OK': {'full': 'Oklahoma', 'two_digit': 'OK', 'FIPS': 40},
        'OR': {'full': 'Oregon', 'two_digit': 'OR', 'FIPS': 41},
        'PA': {'full': 'Pennsylvania', 'two_digit': 'PA', 'FIPS': 42},
        'RI': {'full': 'Rhode Island', 'two_digit': 'RI', 'FIPS': 44},
        'SC': {'full': 'South Carolina', 'two_digit': 'SC', 'FIPS': 45},
        'SD': {'full': 'South Dakota', 'two_digit': 'SD', 'FIPS': 46},
        'TN': {'full': 'Tennessee', 'two_digit': 'TN', 'FIPS': 47},
        'TX': {'full': 'Texas', 'two_digit': 'TX', 'FIPS': 48},
        'UT': {'full': 'Utah', 'two_digit': 'UT', 'FIPS': 49},
        'VT': {'full': 'Vermont', 'two_digit': 'VT', 'FIPS': 50},
        'VA': {'full': 'Virginia', 'two_digit': 'VA', 'FIPS': 51},
        'WA': {'full': 'Washington', 'two_digit': 'WA', 'FIPS': 53},
        'WV': {'full': 'West Virginia', 'two_digit': 'WV', 'FIPS': 54},
        'WI': {'full': 'Wisconsin', 'two_digit': 'WI', 'FIPS': 55},
        'WY': {'full': 'Wyoming', 'two_digit': 'WY', 'FIPS': 56},
        'PR': {'full': 'Puerto Rico', 'two_digit': 'PR', 'FIPS': 72}
    }
    for row in code_hash:
        for value in code_hash[row]:
            if code_hash[row][value] == input:
                return code_hash[row][returnType]
    return None

# %%
# converts district code from the money ball csv to a GEOID
# ex. "CT-HD-59" --> '9059'
# ex. "MN-HD-13A" --> '2713A'
def getGEOID(district_str, leading_zero = False):
    state, chamber, dist_num = district_str.split('-')
    GEOID = str(get_state_code(state)) 
    if leading_zero and len(GEOID) < 2: 
        GEOID= '0' + GEOID
    while len(dist_num) <3: 
        dist_num = '0' + dist_num
    GEOID =  GEOID + dist_num
    return GEOID

# %%
# extracts the chamber type from the district code in the money ball csv
# ex. "CT-HD-59" --> 'HD'
def getChamber(district_str):
    state, chamber, dist_num = district_str.split('-')
    return chamber

# %%
# extracts the district name.  Used for the non-numerical Massachussets 
# districts in place of GEOID matching
def getName(district_str):
    state, chamber, dist_str = district_str.split('-')
    if len(dist_str) < 4 : return ''
    return dist_str

# %% [markdown]
# state,district,favored,confidence,rep_nominee,dem_nominee,incumbent,redistricting_voter_power,anti_gerrymandering_party,geoid,chamber

# %%
#################################################
#  PROCESS + ADD FIELDS TO MONEYBALL MODEL CSV  #
#################################################
def process_moneyball_data(outFile):
    df = pd.read_csv(data_dir / inFile)

    lambdafunc = lambda x: pd.Series(
        getChamber(x['district']),
    )
    df ['chamber'] = df.apply(lambdafunc, axis = 1)

    df.to_csv(data_dir / outFile, index=False, float_format='%.16f')

# %%
def process_combine_data(outname):
    model_df = pd.read_csv(data_dir / 'moneyball-output_8_9_2020.csv')
    cand_df = pd.read_csv(data_dir / 'moneyball-latest-candidates.csv')
    ma_geoids = pd.read_csv(data_dir / 'MA_GEOIDS.csv')
    model_df = model_df[['state', 'district', 'favored', 'confidence', 'anti_gerrymandering_party', 'abs_power']]
    max_vp = model_df['abs_power'].max()
    model_df['abs_power'] = model_df.apply(lambda x: x['abs_power'] / max_vp * 100, axis=1)
    model_df = model_df.rename({'abs_power': 'redistricting_voter_power'}, axis='columns')
    cand_df = cand_df[['district', 'dem_nominee', 'rep_nominee', 'incumbent']]
    merged_df = pd.merge(model_df, cand_df, how='left', on='district')
    merged_df['geoid'] = merged_df.apply(lambda x: ma_geoids[ma_geoids.district == x.district].iloc[0]['geoid'] \
            if x.state == 'MA' \
            else getGEOID(x['district'], leading_zero = True), \
            axis=1)
    merged_df['chamber'] = merged_df.apply(lambda x: getChamber(x['district']), axis=1)
    merged_df.replace({'dem_nominee': {'FALSE': '', 'False': ''}, 'rep_nominee': {'FALSE': '', 'False': ''}}, inplace =True)
    merged_df = merged_df[['state','district','favored','confidence','rep_nominee','dem_nominee','incumbent', \
               'redistricting_voter_power','anti_gerrymandering_party','geoid','chamber']]
    merged_df.to_csv(data_dir / outname, index=False, float_format='%.16f')

# %%
process_moneyball_data('output_7_28_with_nominees.csv', 'processed_data.csv')

# %%
process_combine_data('processed_data_8_11.csv')

# %%
mas = pd.read_csv(data_dir / 'output_7_28_with_nominees.csv')
mas = mas[mas['state']=='MA'][['district', 'geoid']]
mas.to_csv(data_dir / 'MA_GEOIDS.csv', index=False)

# %%
mas = mas[mas['state']=='MA'][['district', 'geoid']]
mas.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-fe59f35214cf> in <module>
# ----> 1 mas = mas[mas['state']=='MA'][['district', 'geoid']]
#       2 mas.head()
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'

# %%
# read in moneyball data
df = pd.read_csv(data_dir / 'processed_data.csv')

# segment to upper and lower chamber
upper_df = df[df['chamber'] == 'SD']
lower_df = df[df['chamber'] == 'HD']

# read in shapefiles 
upper_shp = gpd.read_file(data_dir / 'UPPER_cb_2019_us_sldu_500k/cb_2019_us_sldu_500k.shp')
lower_shp = gpd.read_file(data_dir / 'LOWER_cb_2019_us_sldl_500k/cb_2019_us_sldl_500k.shp')

# read in north carolinas updated district geometry
nc_upper_shp = gpd.read_file(data_dir / 'NC_State_Senate_2020/Senate Consensus Nonpartisan Map v3.shp')
nc_lower_shp = gpd.read_file(data_dir / 'NC_State_House_2020/HB 1020 H Red Comm CSBK-25.shp')

# normalize coordinate system of NC data for integration to census data
nc_upper_shp = nc_upper_shp.to_crs(upper_shp.crs)
nc_lower_shp = nc_lower_shp.to_crs(lower_shp.crs)

# %%
#### replace nc geometry into census shapefile ####

# get GEOID columns for merge
nc_lower_shp['GEOID'] = nc_lower_shp['DISTRICT'].apply(lambda x:\
                                            '37' + str(x).zfill(3))
nc_upper_shp['GEOID'] = nc_upper_shp['DISTRICT'].apply(lambda x:\
                                            '37' + str(x).zfill(3))

# merge
merged_upper_shp = pd.merge(upper_shp, nc_upper_shp, how='left', on='GEOID', suffixes=['', '_y'])
merged_lower_shp = pd.merge(lower_shp, nc_lower_shp, how='left', on='GEOID', suffixes=['', '_y'])

# merge in geometries to the proper column
merged_upper_shp['geometry'] = merged_upper_shp.apply(lambda x:\
                        x['geometry_y'] if x['STATEFP'] == '37'\
                                        else x['geometry'], \
                                        axis = 1)
merged_lower_shp['geometry'] = merged_lower_shp.apply(lambda x:\
                        x['geometry_y'] if x['STATEFP'] == '37'\
                                        else x['geometry'], \
                                        axis = 1)

upper_shp = merged_upper_shp.drop(columns='geometry_y')
lower_shp = merged_lower_shp.drop(columns='geometry_y')

# %%
def pandas_lambda_geolocate(row, df, df_columns, default_values):
    vals = []
    geomatch = df[df['geoid'] == row['GEOID']]
    if len(geomatch.index) < 1:
        #print (f"No match found for GEOID: {row['GEOID']}")
        return pd.Series(default_values)
    elif len(geomatch.index) > 1:
        print(f"More than one match found for GEOID: {row['GEOID']}")
    geomatch = geomatch.iloc[0]
    
    for i in range(0, len(df_columns)):
        vals.append(geomatch[df_columns[i]])

    return pd.Series(vals)

# %%
def get_lean(row, df):
    geomatch = df[df['geoid'] == row['GEOID']]
    if len(geomatch.index) < 1:
        return 'no data'
    elif len(geomatch.index) > 1:
        print(f"More than one match found for GEOID: {row['GEOID']}")
    geomatch = geomatch.iloc[0]
    confidence = geomatch['confidence']
    favored = geomatch['favored']
    if confidence == 'Toss-Up': return confidence
    return confidence + " " + favored

# %%
# helper method parsing districts with characters
def toInt(foo):
    try:
        int(foo)
    except ValueError:
        return foo
    return int(foo)

# %%
# returns full state name, 2 letter postal code, and district from GEOID
def get_district(GEOID, chamber):
    GEOID_str = str(GEOID)
    end_state = 2 if len(GEOID_str) == 5 else 1
    two_letter = get_state_code(int(GEOID_str[0:end_state]), 'two_digit')
    district = two_letter + '-' + chamber + '-' + str(toInt(GEOID_str[end_state:]))
    return district

# %%
def get_full_state(GEOID):
    GEOID_str = str(GEOID)
    end_state = 2 if len(GEOID_str) == 5 else 1
    full = get_state_code(int(GEOID_str[0:end_state]), 'full')
    return full

# %%
def get_postal(GEOID):
    GEOID_str = str(GEOID)
    end_state = 2 if len(GEOID_str) == 5 else 1
    two_letter = get_state_code(int(GEOID_str[0:end_state]), 'two_digit')
    return two_letter

# %%
# add data columns from model to geojson 
df_columns = ['district', 'rep_nominee', 'dem_nominee', 'incumbent', 'anti_gerrymandering_party', 'redistricting_voter_power']
default_values = ['',       '',           '',           '',          '',                            0]

upper_shp[['DISTRICT', 'NOM_R', 'NOM_D', 'INCUMBENT','ANTI_GERRY_PARTY', 'VOTER_POWER']] = upper_shp.apply(
    lambda row: pandas_lambda_geolocate(row, upper_df, df_columns, default_values), axis = 1)
upper_shp['LEAN'] = upper_shp.apply(lambda row: get_lean(row, upper_df), axis = 1)

lower_shp[['DISTRICT', 'NOM_R', 'NOM_D', 'INCUMBENT','ANTI_GERRY_PARTY', 'VOTER_POWER']] = lower_shp.apply(
    lambda row: pandas_lambda_geolocate(row, lower_df, df_columns, default_values), axis = 1)
lower_shp['LEAN'] = lower_shp.apply(lambda row: get_lean(row, lower_df), axis = 1)

# %%
# add district fields to shapes not in the model
lower_shp['DISTRICT'] = lower_shp.apply(lambda row: get_district(row['GEOID'], 'HD') if row['DISTRICT'] == '' 
                        else row['DISTRICT'], axis=1)
upper_shp['DISTRICT'] = upper_shp.apply(lambda row: get_district(row['GEOID'], 'SD') if row['DISTRICT'] == '' 
                        else row['DISTRICT'], axis=1)

# eliminate unneeded columns and order 
upper_shp = upper_shp[['STATEFP', 'GEOID', 'DISTRICT', 'NOM_R', 'NOM_D', 'INCUMBENT','ANTI_GERRY_PARTY', 'LEAN', 'VOTER_POWER', 'geometry']]	
lower_shp = lower_shp[['STATEFP', 'GEOID', 'DISTRICT', 'NOM_R', 'NOM_D', 'INCUMBENT','ANTI_GERRY_PARTY', 'LEAN', 'VOTER_POWER', 'geometry']]

# add full state names and 2 letter state abbreviations to all shapes
upper_shp['FULL'] = upper_shp.apply(lambda row: get_full_state(row['GEOID']), axis=1)
upper_shp['POSTAL'] = upper_shp.apply(lambda row: get_postal(row['GEOID']), axis=1)
lower_shp['FULL'] = lower_shp.apply(lambda row: get_full_state(row['GEOID']), axis=1)
lower_shp['POSTAL'] = lower_shp.apply(lambda row: get_postal(row['GEOID']), axis=1)

# %%
# replace 'FALSE' with blank candidate fields  ('TBA' is the other option)
upper_shp['NOM_R'].replace({'FALSE': ''}, inplace =True)
upper_shp['NOM_D'].replace({'FALSE': ''}, inplace =True)
lower_shp['NOM_R'].replace({'FALSE': ''}, inplace =True)
lower_shp['NOM_D'].replace({'FALSE': ''}, inplace =True)

upper_nonzero_rows = len(upper_shp[upper_shp['VOTER_POWER'] != 0].index)
lower_nonzero_rows = len(lower_shp[lower_shp['VOTER_POWER'] != 0].index)

# %%
# save to GeoJSON format
upper_shp.to_file(out_dir / "upper_state_moneyball.geojson", driver="GeoJSON")
lower_shp.to_file(out_dir / "lower_state_moneyball.geojson", driver="GeoJSON")

# %%
voterpowers = pd.read_csv(data_dir / 'moneyball-output_8_9_2020.csv')

# %%
old_upp_shp = gpd.read_file(out_dir / "upper_state_moneyball.geojson")
old_low_shp = gpd.read_file(out_dir/ "lower_state_moneyball.geojson")

# %%
old_upp_shp = old_upp_shp.sort_values('VOTER_POWER', ascending=False)
old_upp_shp
# Out:
#      STATEFP  GEOID  DISTRICT              NOM_R          NOM_D INCUMBENT  \
# 1461      27  27014  MN-SD-14        Jerry Relph    Aric Putnam         R
# 1177      27  27058  MN-SD-58     Zach Duckworth    Matt Little         D
# 1905      27  27056  MN-SD-56           Dan Hall            TBA         R
# 53        27  27020  MN-SD-20       Rich Draheim      Jon Olson         R
# 1005      27  27054  MN-SD-54  Leilani Holmstadt   Karla Bigham         D
# ...      ...    ...       ...                ...            ...       ...
# 1536      49  49004   UT-SD-4
# 1537      49  49001   UT-SD-1         Jim Whited  Luz Escamilla         D
# 1538      30  30041  MT-SD-41
# 1539      17  17004   IL-SD-4
# 1957      28  28004   MS-SD-4
#
#      ANTI_GERRY_PARTY     LEAN  VOTER_POWER         FULL POSTAL  \
# 1461                R  Toss-Up    71.420330    Minnesota     MN
# 1177                R  Toss-Up    70.861565    Minnesota     MN
# 1905                R  Toss-Up    66.865501    Minnesota     MN
# 53                  R   Lean R    56.004487    Minnesota     MN
# 1005                R   Lean D    52.370745    Minnesota     MN
# ...               ...      ...          ...          ...    ...
# 1536                   no data     0.000000         Utah     UT
# 1537             None   Safe D     0.000000         Utah     UT
# 1538                   no data     0.000000      Montana     MT
# 1539                   no data     0.000000     Illinois     IL
# 1957                   no data     0.000000  Mississippi     MS
#
#                                                geometry
# 1461  POLYGON ((-94.26945 45.54787, -94.26577 45.549...
# 1177  POLYGON ((-93.31856 44.65209, -93.31835 44.681...
# 1905  POLYGON ((-93.39901 44.75362, -93.39901 44.753...
# 53    POLYGON ((-93.96578 44.39064, -93.96430 44.392...
# 1005  POLYGON ((-93.04501 44.87459, -93.04533 44.878...
# ...                                                 ...
# 1536  POLYGON ((-111.86497 40.66157, -111.86475 40.6...
# 1537  POLYGON ((-112.26022 40.76909, -112.19598 40.8...
# 1538  POLYGON ((-112.06372 46.70422, -112.01176 46.7...
# 1539  POLYGON ((-87.92062 41.88975, -87.92057 41.897...
# 1957  POLYGON ((-89.08862 34.75714, -89.08854 34.771...
#
# [1958 rows x 12 columns]

# %%
cand_names = pd.read_csv(data_dir / 'moneyball-latest-candidates.csv')
cand_names = cand_names[['district', 'dem_nominee', 'rep_nominee']]
cand_names = cand_names.rename({'district': 'DISTRICT', 'dem_nominee': 'NOM_D', 'rep_nominee': 'NOM_R'}, axis='columns')
old_upp_shp_merge = pd.merge(old_upp_shp, cand_names, how='left', on='DISTRICT', suffixes=['', '_y'])
old_upp_shp_merge 
old_upp_shp_merge
# Out:
#        NaN                     NaN
# 1636                            NaN                     NaN
# 1637                            NaN                     NaN
# 1638                          FALSE                   FALSE
# 1639                          FALSE                   FALSE
# 1640  Jestine Ianotti (Independent)           Jason Brodeur
# 1641                            NaN                     NaN
# 1642                            NaN                     NaN
# 1643                          FALSE                   FALSE
# 1644                          FALSE                   FALSE
# 1645                            NaN                     NaN
# 1646                            NaN                     NaN
# 1647                            NaN                     NaN
# 1648                            NaN                     NaN
# 1649                            NaN                     NaN
# 1650                            NaN                     NaN
# 1651                            NaN                     NaN
# 1652                            NaN                     NaN
# 1653                            NaN                     NaN
# 1654                            NaN                     NaN
# 1655                            NaN                     NaN
# 1656                            NaN                     NaN
# 1657                            NaN                     NaN
# 1658                  Mike McCorkle        Gene Suellentrop
# 1659                     Pat Pettey      Dianna Whittington
# 1660                            NaN                     NaN
# 1661                            NaN                     NaN
# 1662                            NaN                     NaN
# 1663                            NaN                     NaN
# 1664                    Erin Murphy         Sharon Anderson
# 1665                            NaN                     NaN
# 1666                            NaN                     NaN
# 1667                            NaN                     NaN
# 1668                          FALSE                   FALSE
# 1669                          FALSE                   FALSE
# 1670                            TBA           Alciro Deacon
# 1671                            TBA                     TBA
# 1672                            NaN                     NaN
# 1673                            NaN                     NaN
# 1674                            NaN                     NaN
# 1675                            TBA                     TBA
# 1676                            NaN                     NaN
# 1677                            NaN                     NaN
# 1678                            NaN                     NaN
# 1679                            NaN                     NaN
# 1680                            TBA             John Morton
# 1681                            NaN                     NaN
# 1682                            NaN                     NaN
# 1683                            NaN                     NaN
# 1684                            NaN                     NaN
# 1685                            NaN                     NaN
# 1686                            NaN                     NaN
# 1687                            NaN                     NaN
# 1688                          FALSE                   FALSE
# 1689                            NaN                     NaN
# 1690                            NaN                     NaN
# 1691                            NaN                     NaN
# 1692                            NaN                     NaN
# 1693                            TBA            Scott Barker
# 1694                            NaN                     NaN
# 1695                          FALSE                   FALSE
# 1696                   Mimi Stewart           Rodney Deskin
# 1697               Jacob Candelaria       Manuel Lardizabal
# 1698                            NaN                     NaN
# 1699                            NaN                     NaN
# 1700                            NaN                     NaN
# 1701                            NaN                     NaN
# 1702                            NaN                     NaN
# 1703                            NaN                     NaN
# 1704                            NaN                     NaN
# 1705                Michael Padilla             Mary Ingham
# 1706                   Stan Albaugh              John Crane
# 1707                            NaN                     NaN
# 1708                            NaN                     NaN
# 1709                            NaN                     NaN
# 1710                            NaN                     NaN
# 1711                            NaN                     NaN
# 1712                            NaN                     NaN
# 1713                            NaN                     NaN
# 1714                            NaN                     NaN
# 1715                            NaN                     NaN
# 1716                            NaN                     NaN
# 1717                            NaN                     NaN
# 1718                            TBA           Paul Anderson
# 1719                            NaN                     NaN
# 1720                            NaN                     NaN
# 1721                Christine Cohen          Joseph LaPorta
# 1722                            NaN                     NaN
# 1723                            NaN                     NaN
# 1724                   Kate Luthner      Michelle R. Benson
# 1725                            NaN                     NaN
# 1726                            NaN                     NaN
# 1727                            NaN                     NaN
# 1728                            NaN                     NaN
# 1729                            NaN                     NaN
# 1730                            NaN                     NaN
# 1731                            NaN                     NaN
# 1732                  Rachel Willis                     TBA
# 1733                            NaN                     NaN
# 1734                    Dinah Sykes            Tom Bickimer
# 1735                            NaN                     NaN
# 1736                    Rick Dunham           Tom J. Dugger
# 1737                          FALSE                   FALSE
# 1738                            NaN                     NaN
# 1739                            NaN                     NaN
# 1740                            NaN                     NaN
# 1741                            NaN                     NaN
# 1742                            NaN                     NaN
# 1743                            NaN                     NaN
# 1744                            NaN                     NaN
# 1745                          FALSE                   FALSE
# 1746                Jay Stittleburg       Brandon Creighton
# 1747                            NaN                     NaN
# 1748                Michael Antalan          Lois Kolkhorst
# 1749                            NaN                     NaN
# 1750                            NaN                     NaN
# 1751                            NaN                     NaN
# 1752                            NaN                     NaN
# 1753                            NaN                     NaN
# 1754                            NaN                     NaN
# 1755                            NaN                     NaN
# 1756                            NaN                     NaN
# 1757                            NaN                     NaN
# 1758                            NaN                     NaN
# 1759                       Jim Ward           Mike Petersen
# 1760                            NaN                     NaN
# 1761                            NaN                     NaN
# 1762                            NaN                     NaN
# 1763                            NaN                     NaN
# 1764                            NaN                     NaN
# 1765                            NaN                     NaN
# 1766                            NaN                     NaN
# 1767                            NaN                     NaN
# 1768                            NaN                     NaN
# 1769                            NaN                     NaN
# 1770                   John Kirkman              Jim Burgin
# 1771                            NaN                     NaN
# 1772                            NaN                     NaN
# 1773                            NaN                     NaN
# 1774                            NaN                     NaN
# 1775          Shirley Green Frayson                     TBA
# 1776                     Ryan Craig             Jim Hendren
# 1777                            NaN                     NaN
# 1778                            NaN                     NaN
# 1779                            NaN                     NaN
# 1780                            NaN                     NaN
# 1781                            NaN                     NaN
# 1782             Jerry Ortiz Y Pino        Lisa Meyer-Hagen
# 1783                    Linda Lopez         Marylinda Price
# 1784                          FALSE                   FALSE
# 1785                          FALSE                   FALSE
# 1786                          FALSE                   FALSE
# 1787                          FALSE                   FALSE
# 1788                            NaN                     NaN
# 1789                            NaN                     NaN
# 1790                    Eddie Lucio        Vanessa Tijerina
# 1791                            NaN                     NaN
# 1792                          FALSE                   FALSE
# 1793                            TBA            George Logan
# 1794                            NaN                     NaN
# 1795                            TBA                     TBA
# 1796                          FALSE                   FALSE
# 1797                            NaN                     NaN
# 1798                            NaN                     NaN
# 1799                Tabitha Bartley          Brian Buchanan
# 1800                  Stacey Knoell              Julia Lynn
# 1801                      Mary Ware         Vail Fruechting
# 1802                            NaN                     NaN
# 1803                            NaN                     NaN
# 1804                            NaN                     NaN
# 1805                            NaN                     NaN
# 1806                            NaN                     NaN
# 1807                          FALSE                   FALSE
# 1808                      John Kane             Tom Killion
# 1809                            NaN                     NaN
# 1810                            NaN                     NaN
# 1811                            NaN                     NaN
# 1812                            NaN                     NaN
# 1813                            NaN                     NaN
# 1814                            NaN                     NaN
# 1815                            NaN                     NaN
# 1816                            NaN                     NaN
# 1817                            NaN                     NaN
# 1818                            NaN                     NaN
# 1819                            NaN                     NaN
# 1820                   Greg Clausen         Jose W. Jimenez
# 1821                            NaN                     NaN
# 1822                            NaN                     NaN
# 1823                    Edgar Pando               Bud Estes
# 1824                  Wendy Budetti                     TBA
# 1825                     Dan Sparks            Gene Dornink
# 1826                     Rick Lopes        Gennaro Bizzarro
# 1827                          FALSE                   FALSE
# 1828                            NaN                     NaN
# 1829                            NaN                     NaN
# 1830                            NaN                     NaN
# 1831                            NaN                     NaN
# 1832                          FALSE                   FALSE
# 1833                  Julie Kushner           Susan Chapman
# 1834                            NaN                     NaN
# 1835                            NaN                     NaN
# 1836                            NaN                     NaN
# 1837                            NaN                     NaN
# 1838                            NaN                     NaN
# 1839                            NaN                     NaN
# 1840                            NaN                     NaN
# 1841                            NaN                     NaN
# 1842                            NaN                     NaN
# 1843                          FALSE                   FALSE
# 1844                          FALSE                   FALSE
# 1845                            TBA          Kristen O'Shea
# 1846                            NaN                     NaN
# 1847                            NaN                     NaN
# 1848                            NaN                     NaN
# 1849                            NaN                     NaN
# 1850                            NaN                     NaN
# 1851                            NaN                     NaN
# 1852                            NaN                     NaN
# 1853                            NaN                     NaN
# 1854             Shawna Mott-Wright              Dave Rader
# 1855                            NaN                     NaN
# 1856                  Steve Cassano           Matthew Corey
# 1857                            NaN                     NaN
# 1858                            NaN                     NaN
# 1859                            NaN                     NaN
# 1860                            NaN                     NaN
# 1861                            NaN                     NaN
# 1862                            NaN                     NaN
# 1863                            NaN                     NaN
# 1864                            NaN                     NaN
# 1865                            NaN                     NaN
# 1866                      Luke Bohm          Ed Charbonneau
# 1867                    Joy Koesten                     TBA
# 1868                            NaN                     NaN
# 1869                            NaN                     NaN
# 1870                Steve Samuelson                     TBA
# 1871                            NaN                     NaN
# 1872                            NaN                     NaN
# 1873                            NaN                     NaN
# 1874                            NaN                     NaN
# 1875                            NaN                     NaN
# 1876                            NaN                     NaN
# 1877                            NaN                     NaN
# 1878                            NaN                     NaN
# 1879                            NaN                     NaN
# 1880                            NaN                     NaN
# 1881                            NaN                     NaN
# 1882                            NaN                     NaN
# 1883                            NaN                     NaN
# 1884                            NaN                     NaN
# 1885                            NaN                     NaN
# 1886                            NaN                     NaN
# 1887                    Harold Pope              Sander Rue
# 1888                            NaN                     NaN
# 1889                            NaN                     NaN
# 1890                            NaN                     NaN
# 1891                     Bill Brown          Katrina Shealy
# 1892                Jeffrey Pittman             Kevin Braun
# 1893                            NaN                     NaN
# 1894                            NaN                     NaN
# 1895                            NaN                     NaN
# 1896                          FALSE                   FALSE
# 1897                          FALSE                   FALSE
# 1898                            NaN                     NaN
# 1899                            NaN                     NaN
# 1900                            TBA           Karin Housley
# 1901                            NaN                     NaN
# 1902                            NaN                     NaN
# 1903                            NaN                     NaN
# 1904                            NaN                     NaN
# 1905                    Primary TBA                Dan Hall
# 1906                            NaN                     NaN
# 1907                            NaN                     NaN
# 1908          Mary Daugherty Abrams               Len Suzio
# 1909                          FALSE                   FALSE
# 1910                            NaN                     NaN
# 1911                            NaN                     NaN
# 1912                            NaN                     NaN
# 1913                    Ryan Olexia          Chris McDaniel
# 1914                            NaN                     NaN
# 1915                            NaN                     NaN
# 1916                            NaN                     NaN
# 1917               Daniel Ivey-Soto           Sandra Rausch
# 1918                          FALSE                   FALSE
# 1919                          FALSE                   FALSE
# 1920                            NaN                     NaN
# 1921                            NaN                     NaN
# 1922                            NaN                     NaN
# 1923                 William Soules            David Gallus
# 1924                          FALSE                   FALSE
# 1925                          FALSE                   FALSE
# 1926                            NaN                     NaN
# 1927                            NaN                     NaN
# 1928                            NaN                     NaN
# 1929                            NaN                     NaN
# 1930                            NaN                     NaN
# 1931                            NaN                     NaN
# 1932                            NaN                     NaN
# 1933                            NaN                     NaN
# 1934              DeAndrea Salvador            Joshua Niday
# 1935                          FALSE                   FALSE
# 1936                            NaN                     NaN
# 1937                            NaN                     NaN
# 1938                            NaN                     NaN
# 1939                            NaN                     NaN
# 1940                            NaN                     NaN
# 1941                            NaN                     NaN
# 1942                            NaN                     NaN
# 1943                            NaN                     NaN
# 1944                            NaN                     NaN
# 1945                            NaN                     NaN
# 1946                            NaN                     NaN
# 1947                          FALSE                   FALSE
# 1948                          FALSE                   FALSE
# 1949                          FALSE                   FALSE
# 1950                            NaN                     NaN
# 1951                            NaN                     NaN
# 1952            Aaron Wojciechowski               Dan Feyen
# 1953                            NaN                     NaN
# 1954                            NaN                     NaN
# 1955                          FALSE                   FALSE
# 1956                            NaN                     NaN
# 1957                            NaN                     NaN

# %%
pd.set_option('display.max_rows', None)

# %%
old_upp_shp_merge
# Out:
#        NaN                     NaN
# 1636                            NaN                     NaN
# 1637                            NaN                     NaN
# 1638                          FALSE                   FALSE
# 1639                          FALSE                   FALSE
# 1640  Jestine Ianotti (Independent)           Jason Brodeur
# 1641                            NaN                     NaN
# 1642                            NaN                     NaN
# 1643                          FALSE                   FALSE
# 1644                          FALSE                   FALSE
# 1645                            NaN                     NaN
# 1646                            NaN                     NaN
# 1647                            NaN                     NaN
# 1648                            NaN                     NaN
# 1649                            NaN                     NaN
# 1650                            NaN                     NaN
# 1651                            NaN                     NaN
# 1652                            NaN                     NaN
# 1653                            NaN                     NaN
# 1654                            NaN                     NaN
# 1655                            NaN                     NaN
# 1656                            NaN                     NaN
# 1657                            NaN                     NaN
# 1658                  Mike McCorkle        Gene Suellentrop
# 1659                     Pat Pettey      Dianna Whittington
# 1660                            NaN                     NaN
# 1661                            NaN                     NaN
# 1662                            NaN                     NaN
# 1663                            NaN                     NaN
# 1664                    Erin Murphy         Sharon Anderson
# 1665                            NaN                     NaN
# 1666                            NaN                     NaN
# 1667                            NaN                     NaN
# 1668                          FALSE                   FALSE
# 1669                          FALSE                   FALSE
# 1670                            TBA           Alciro Deacon
# 1671                            TBA                     TBA
# 1672                            NaN                     NaN
# 1673                            NaN                     NaN
# 1674                            NaN                     NaN
# 1675                            TBA                     TBA
# 1676                            NaN                     NaN
# 1677                            NaN                     NaN
# 1678                            NaN                     NaN
# 1679                            NaN                     NaN
# 1680                            TBA             John Morton
# 1681                            NaN                     NaN
# 1682                            NaN                     NaN
# 1683                            NaN                     NaN
# 1684                            NaN                     NaN
# 1685                            NaN                     NaN
# 1686                            NaN                     NaN
# 1687                            NaN                     NaN
# 1688                          FALSE                   FALSE
# 1689                            NaN                     NaN
# 1690                            NaN                     NaN
# 1691                            NaN                     NaN
# 1692                            NaN                     NaN
# 1693                            TBA            Scott Barker
# 1694                            NaN                     NaN
# 1695                          FALSE                   FALSE
# 1696                   Mimi Stewart           Rodney Deskin
# 1697               Jacob Candelaria       Manuel Lardizabal
# 1698                            NaN                     NaN
# 1699                            NaN                     NaN
# 1700                            NaN                     NaN
# 1701                            NaN                     NaN
# 1702                            NaN                     NaN
# 1703                            NaN                     NaN
# 1704                            NaN                     NaN
# 1705                Michael Padilla             Mary Ingham
# 1706                   Stan Albaugh              John Crane
# 1707                            NaN                     NaN
# 1708                            NaN                     NaN
# 1709                            NaN                     NaN
# 1710                            NaN                     NaN
# 1711                            NaN                     NaN
# 1712                            NaN                     NaN
# 1713                            NaN                     NaN
# 1714                            NaN                     NaN
# 1715                            NaN                     NaN
# 1716                            NaN                     NaN
# 1717                            NaN                     NaN
# 1718                            TBA           Paul Anderson
# 1719                            NaN                     NaN
# 1720                            NaN                     NaN
# 1721                Christine Cohen          Joseph LaPorta
# 1722                            NaN                     NaN
# 1723                            NaN                     NaN
# 1724                   Kate Luthner      Michelle R. Benson
# 1725                            NaN                     NaN
# 1726                            NaN                     NaN
# 1727                            NaN                     NaN
# 1728                            NaN                     NaN
# 1729                            NaN                     NaN
# 1730                            NaN                     NaN
# 1731                            NaN                     NaN
# 1732                  Rachel Willis                     TBA
# 1733                            NaN                     NaN
# 1734                    Dinah Sykes            Tom Bickimer
# 1735                            NaN                     NaN
# 1736                    Rick Dunham           Tom J. Dugger
# 1737                          FALSE                   FALSE
# 1738                            NaN                     NaN
# 1739                            NaN                     NaN
# 1740                            NaN                     NaN
# 1741                            NaN                     NaN
# 1742                            NaN                     NaN
# 1743                            NaN                     NaN
# 1744                            NaN                     NaN
# 1745                          FALSE                   FALSE
# 1746                Jay Stittleburg       Brandon Creighton
# 1747                            NaN                     NaN
# 1748                Michael Antalan          Lois Kolkhorst
# 1749                            NaN                     NaN
# 1750                            NaN                     NaN
# 1751                            NaN                     NaN
# 1752                            NaN                     NaN
# 1753                            NaN                     NaN
# 1754                            NaN                     NaN
# 1755                            NaN                     NaN
# 1756                            NaN                     NaN
# 1757                            NaN                     NaN
# 1758                            NaN                     NaN
# 1759                       Jim Ward           Mike Petersen
# 1760                            NaN                     NaN
# 1761                            NaN                     NaN
# 1762                            NaN                     NaN
# 1763                            NaN                     NaN
# 1764                            NaN                     NaN
# 1765                            NaN                     NaN
# 1766                            NaN                     NaN
# 1767                            NaN                     NaN
# 1768                            NaN                     NaN
# 1769                            NaN                     NaN
# 1770                   John Kirkman              Jim Burgin
# 1771                            NaN                     NaN
# 1772                            NaN                     NaN
# 1773                            NaN                     NaN
# 1774                            NaN                     NaN
# 1775          Shirley Green Frayson                     TBA
# 1776                     Ryan Craig             Jim Hendren
# 1777                            NaN                     NaN
# 1778                            NaN                     NaN
# 1779                            NaN                     NaN
# 1780                            NaN                     NaN
# 1781                            NaN                     NaN
# 1782             Jerry Ortiz Y Pino        Lisa Meyer-Hagen
# 1783                    Linda Lopez         Marylinda Price
# 1784                          FALSE                   FALSE
# 1785                          FALSE                   FALSE
# 1786                          FALSE                   FALSE
# 1787                          FALSE                   FALSE
# 1788                            NaN                     NaN
# 1789                            NaN                     NaN
# 1790                    Eddie Lucio        Vanessa Tijerina
# 1791                            NaN                     NaN
# 1792                          FALSE                   FALSE
# 1793                            TBA            George Logan
# 1794                            NaN                     NaN
# 1795                            TBA                     TBA
# 1796                          FALSE                   FALSE
# 1797                            NaN                     NaN
# 1798                            NaN                     NaN
# 1799                Tabitha Bartley          Brian Buchanan
# 1800                  Stacey Knoell              Julia Lynn
# 1801                      Mary Ware         Vail Fruechting
# 1802                            NaN                     NaN
# 1803                            NaN                     NaN
# 1804                            NaN                     NaN
# 1805                            NaN                     NaN
# 1806                            NaN                     NaN
# 1807                          FALSE                   FALSE
# 1808                      John Kane             Tom Killion
# 1809                            NaN                     NaN
# 1810                            NaN                     NaN
# 1811                            NaN                     NaN
# 1812                            NaN                     NaN
# 1813                            NaN                     NaN
# 1814                            NaN                     NaN
# 1815                            NaN                     NaN
# 1816                            NaN                     NaN
# 1817                            NaN                     NaN
# 1818                            NaN                     NaN
# 1819                            NaN                     NaN
# 1820                   Greg Clausen         Jose W. Jimenez
# 1821                            NaN                     NaN
# 1822                            NaN                     NaN
# 1823                    Edgar Pando               Bud Estes
# 1824                  Wendy Budetti                     TBA
# 1825                     Dan Sparks            Gene Dornink
# 1826                     Rick Lopes        Gennaro Bizzarro
# 1827                          FALSE                   FALSE
# 1828                            NaN                     NaN
# 1829                            NaN                     NaN
# 1830                            NaN                     NaN
# 1831                            NaN                     NaN
# 1832                          FALSE                   FALSE
# 1833                  Julie Kushner           Susan Chapman
# 1834                            NaN                     NaN
# 1835                            NaN                     NaN
# 1836                            NaN                     NaN
# 1837                            NaN                     NaN
# 1838                            NaN                     NaN
# 1839                            NaN                     NaN
# 1840                            NaN                     NaN
# 1841                            NaN                     NaN
# 1842                            NaN                     NaN
# 1843                          FALSE                   FALSE
# 1844                          FALSE                   FALSE
# 1845                            TBA          Kristen O'Shea
# 1846                            NaN                     NaN
# 1847                            NaN                     NaN
# 1848                            NaN                     NaN
# 1849                            NaN                     NaN
# 1850                            NaN                     NaN
# 1851                            NaN                     NaN
# 1852                            NaN                     NaN
# 1853                            NaN                     NaN
# 1854             Shawna Mott-Wright              Dave Rader
# 1855                            NaN                     NaN
# 1856                  Steve Cassano           Matthew Corey
# 1857                            NaN                     NaN
# 1858                            NaN                     NaN
# 1859                            NaN                     NaN
# 1860                            NaN                     NaN
# 1861                            NaN                     NaN
# 1862                            NaN                     NaN
# 1863                            NaN                     NaN
# 1864                            NaN                     NaN
# 1865                            NaN                     NaN
# 1866                      Luke Bohm          Ed Charbonneau
# 1867                    Joy Koesten                     TBA
# 1868                            NaN                     NaN
# 1869                            NaN                     NaN
# 1870                Steve Samuelson                     TBA
# 1871                            NaN                     NaN
# 1872                            NaN                     NaN
# 1873                            NaN                     NaN
# 1874                            NaN                     NaN
# 1875                            NaN                     NaN
# 1876                            NaN                     NaN
# 1877                            NaN                     NaN
# 1878                            NaN                     NaN
# 1879                            NaN                     NaN
# 1880                            NaN                     NaN
# 1881                            NaN                     NaN
# 1882                            NaN                     NaN
# 1883                            NaN                     NaN
# 1884                            NaN                     NaN
# 1885                            NaN                     NaN
# 1886                            NaN                     NaN
# 1887                    Harold Pope              Sander Rue
# 1888                            NaN                     NaN
# 1889                            NaN                     NaN
# 1890                            NaN                     NaN
# 1891                     Bill Brown          Katrina Shealy
# 1892                Jeffrey Pittman             Kevin Braun
# 1893                            NaN                     NaN
# 1894                            NaN                     NaN
# 1895                            NaN                     NaN
# 1896                          FALSE                   FALSE
# 1897                          FALSE                   FALSE
# 1898                            NaN                     NaN
# 1899                            NaN                     NaN
# 1900                            TBA           Karin Housley
# 1901                            NaN                     NaN
# 1902                            NaN                     NaN
# 1903                            NaN                     NaN
# 1904                            NaN                     NaN
# 1905                    Primary TBA                Dan Hall
# 1906                            NaN                     NaN
# 1907                            NaN                     NaN
# 1908          Mary Daugherty Abrams               Len Suzio
# 1909                          FALSE                   FALSE
# 1910                            NaN                     NaN
# 1911                            NaN                     NaN
# 1912                            NaN                     NaN
# 1913                    Ryan Olexia          Chris McDaniel
# 1914                            NaN                     NaN
# 1915                            NaN                     NaN
# 1916                            NaN                     NaN
# 1917               Daniel Ivey-Soto           Sandra Rausch
# 1918                          FALSE                   FALSE
# 1919                          FALSE                   FALSE
# 1920                            NaN                     NaN
# 1921                            NaN                     NaN
# 1922                            NaN                     NaN
# 1923                 William Soules            David Gallus
# 1924                          FALSE                   FALSE
# 1925                          FALSE                   FALSE
# 1926                            NaN                     NaN
# 1927                            NaN                     NaN
# 1928                            NaN                     NaN
# 1929                            NaN                     NaN
# 1930                            NaN                     NaN
# 1931                            NaN                     NaN
# 1932                            NaN                     NaN
# 1933                            NaN                     NaN
# 1934              DeAndrea Salvador            Joshua Niday
# 1935                          FALSE                   FALSE
# 1936                            NaN                     NaN
# 1937                            NaN                     NaN
# 1938                            NaN                     NaN
# 1939                            NaN                     NaN
# 1940                            NaN                     NaN
# 1941                            NaN                     NaN
# 1942                            NaN                     NaN
# 1943                            NaN                     NaN
# 1944                            NaN                     NaN
# 1945                            NaN                     NaN
# 1946                            NaN                     NaN
# 1947                          FALSE                   FALSE
# 1948                          FALSE                   FALSE
# 1949                          FALSE                   FALSE
# 1950                            NaN                     NaN
# 1951                            NaN                     NaN
# 1952            Aaron Wojciechowski               Dan Feyen
# 1953                            NaN                     NaN
# 1954                            NaN                     NaN
# 1955                          FALSE                   FALSE
# 1956                            NaN                     NaN
# 1957                            NaN                     NaN
